# %%
from pixt_testmodule import ModelLoader,ModelTester


# load model
root_dir = "/home/irteam/junghye-dcloud-dir/Pixt/code/Pixt/outputs/pixt_baseline/lightning_logs/version_105"
model_loader = ModelLoader(root_dir=root_dir)
loaded_model = model_loader.load_model()

print(loaded_model)
# Out:
# BaselineLitModule(
#   (_clip_model): CLIP(
#     (visual): ModifiedResNet(
#       (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU(inplace=True)
#       (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu3): ReLU(inplace=True)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
import sys
sys.path.append('/home/irteam/junghye-dcloud-dir/Pixt/code/Pixt/dataset/transform')
from image_transform import Pixt_ImageTransform
# define image_paths
image_paths=['/home/irteam/junghye-dcloud-dir/Pixt/code/Pixt/data/dataset1/1.webp','/home/irteam/junghye-dcloud-dir/Pixt/code/Pixt/data/dataset1/2.webp']

ann_dir='/home/irteam/junghye-dcloud-dir/Pixt/code/Pixt/data/annotation/annotation_merged_remove_gap.csv'

model_tester=ModelTester(loaded_model,Pixt_ImageTransform(),image_paths,ann_dir)

# %%
model_tester.show_image()

# %%
model_tester.test_step()
# Out:
# {'1.webp': {'prediction': {'Motion graphics(모션그래픽)': 0.010895,
#    'Motion screen(모션스크린)': 0.010315,
#    'Motion sauce(모션소스)': 0.007317,
#    'motion(모션)': 0.006927,
#    'Chromaki Motion(크로마키모션)': 0.003796,
#    'Governor -General of Korea(조선총독부)': 0.003073,
#    'Chromaki(크로마키)': 0.002712,
#    'Green screen motion(그린스크린모션)': 0.001793,
#    'Korea(KOREA)': 0.001671,
#    'korea(korea)': 0.001671},
#   'true_label': ['light(조명)',
#    'tree(나무)',
#    'motion(모션)',
#    'Green screen(그린스크린)',
#    'winter(겨울)',
#    'christmas(크리스마스)',
#    'Santa(산타)',
#    'Carol(캐롤)',
#    'Motion graphics(모션그래픽)',
#    'bulb(전구)',
#    'tree(트리)',
#    'decoration(장식)',
#    'december(12월)',
#    'Year-end(연말)',
#    'Christmas(성탄절)']},
#  '2.webp': {'prediction': {'Motion graphics(모션그래픽)': 0.010895,
#    'Motion screen(모션스크린)': 0.010315,
#    'Motion sauce(모션소스)': 0.007317,
#    'motion(모션)': 0.006927,
#    'Chromaki Motion(크로마키모션)': 0.003796,
# ...
