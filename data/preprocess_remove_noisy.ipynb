# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
number = 1
df = pd.read_csv("./annotation/annotation_merged_remove_gap.csv")
dataset_number = df.iloc[number]["dataset"]
image_number = df.iloc[number]["image_number"]

path = "./" + str(dataset_number) + "/" + str(image_number) + ".webp"
image = img.imread(path)

plt.imshow(image)
plt.show()


df.iloc[number]["tags_ko"]
# Out:
# "['시골', '일몰', '마을', '구름', '지붕', '전경', '산', '강물', '강', '타임랩스', '강가', '저수지', '저수지마을', 'timelapse', '시골집', '시골마을', '정겨운', '정겹다', '고향']"
