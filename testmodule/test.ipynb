# %%
from pixt_testmodule import ModelLoader,ModelTester


# load model
root_dir = "/home/irteam/junghye-dcloud-dir/Pixt/code/Pixt/outputs/pixt_baseline/lightning_logs/version_208"
model_loader = ModelLoader(root_dir=root_dir)
loaded_model = model_loader.load_model()

print(loaded_model)
# Out:
# BaselineLitModule(
#   (_clip_model): CLIP(
#     (visual): ModifiedResNet(
#       (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu2): ReLU(inplace=True)
#       (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu3): ReLU(inplace=True)
#       (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
import sys
sys.path.append('/home/irteam/junghye-dcloud-dir/Pixt/code/Pixt/dataset/transform')
from image_transform import Pixt_ValidationTest_Transform
# define image_paths
image_paths=['/home/irteam/junghye-dcloud-dir/Pixt/code/Pixt/data/dataset1/3.webp','/home/irteam/junghye-dcloud-dir/Pixt/code/Pixt/data/dataset1/4.webp']+\
            ['/home/irteam/junghye-dcloud-dir/Pixt/code/Pixt/data/dataset1/5.webp','/home/irteam/junghye-dcloud-dir/Pixt/code/Pixt/data/dataset1/6.webp']

ann_dir='/home/irteam/junghye-dcloud-dir/Pixt/code/Pixt/data/annotation/annotation_remove_mgf/train_reduction.csv'

model_tester=ModelTester(loaded_model,Pixt_ValidationTest_Transform(),image_paths,ann_dir)

# %%
model_tester.show_image()

# %%
model_tester.test_step()
# Out:
# {'3.webp': {'prediction': {'farming(농사)': 0.026657,
#    'Farming(파밍)': 0.026657,
#    'Gas range(가스레인지)': 0.022095,
#    'roadside(길가)': 0.019501,
#    'turbine(터빈)': 0.013397,
#    'saltern(염전)': 0.012589,
#    'Towering(솟아)': 0.012589,
#    'Salt field(소금밭)': 0.011826,
#    'salt(소금)': 0.011108,
#    'Low salt(저염식)': 0.010437},
#   'true_label': [['ocean(바다)',
#     'farming(농사)',
#     'foreshore(갯벌)',
#     'saltern(염전)',
#     'salt(소금)']]},
#  '4.webp': {'prediction': {'Cloud(cloud)': 0.008591,
#    'night sky(밤하늘)': 0.008591,
#    'cloud(구름)': 0.008591,
#    'Actual cloud(실구름)': 0.008591,
#    'silhouette(실루엣)': 0.008072,
#    'evening sky(저녁하늘)': 0.008072,
#    'sunset(sunset)': 0.007584,
#    'Legend(전설)': 0.007584,
#    'Sunset(선셋)': 0.007584,
#    'Calm(잔잔)': 0.007122},
#   'true_label': [['tree(나무)',
#     'sunset(일몰)',
#     'nature(자연)',
#     'ocean(바다)',
#     'sun(해)',
#     'mountain(산)',
#     'sunset(노을)',
#     'Beach(바닷가)',
#     'pine tree(소나무)',
# ...

# %%
image_paths=['/home/irteam/junghye-dcloud-dir/Pixt/code/Pixt/data/dataset1/2.webp']

ann_dir='/home/irteam/junghye-dcloud-dir/Pixt/code/Pixt/data/annotation/annotation_d1/remove_mgf/annotation_remove_mgf_d1.csv'

model_tester=ModelTester(loaded_model,Pixt_ValidationTest_Transform(),image_paths,ann_dir)

# %%
model_tester.show_image()

# %%
model_tester.test_step()
# Out:
# {'2.webp': {'prediction': {'Harbor(항구)': 0.004749,
#    'Sunin General(선인장군락지)': 0.004463,
#    'Mapo(마포)': 0.004463,
#    'Recognition Moonpanning Shot(인정문패닝샷)': 0.004192,
#    'Telephoto(망원)': 0.004192,
#    'Overseas(해외)': 0.004192,
#    'Teletubby(텔레토비)': 0.004192,
#    'Ship(선박)': 0.003937,
#    "Udo's sea and clouds(해가지는우도의바다와구름)": 0.003937,
#    'ship(ship)': 0.003937},
#   'true_label': [['countryside(시골)',
#     'sunset(일몰)',
#     'Town(마을)',
#     'cloud(구름)',
#     'roof(지붕)',
#     'Panorama(전경)',
#     'mountain(산)',
#     'River(강물)',
#     'river(강)',
#     'Time Labs(타임랩스)',
#     'riverside(강가)',
#     'Reservoir(저수지)',
#     'Timelapse(timelapse)']]}}
# ...
